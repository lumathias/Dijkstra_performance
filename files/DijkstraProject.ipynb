# %%
# !pip install -q networkx codecarbon pandas matplotlib scipy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.7/258.7 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 33.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 2.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.46.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.2 which is incompatible.

# %%
import os
import random
import time
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from scipy import stats
from codecarbon import EmissionsTracker

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# %%
class MinHeap:
    def __init__(self, array):
        self.vertexMap = {idx: idx for idx in range(len(array))}
        self.heap = self.buildHeap(array)

    def isEmpty(self): return len(self.heap) == 0

    def buildHeap(self, array):
        firstParentIdx = (len(array) - 2) // 2
        for currentIdx in reversed(range(firstParentIdx + 1)):
            self.siftDown(currentIdx, len(array) - 1, array)
        return array

    def siftDown(self, currentIdx, endIdx, heap):
        child_one_idx = currentIdx * 2 + 1
        while child_one_idx <= endIdx:
            child_two_idx = currentIdx * 2 + 2 if currentIdx * 2 + 2 <= endIdx else -1
            if child_two_idx != -1 and heap[child_two_idx][1] < heap[child_one_idx][1]:
                idx_to_swap = child_two_idx
            else:
                idx_to_swap = child_one_idx
            if heap[idx_to_swap][1] < heap[currentIdx][1]:
                self.swap(currentIdx, idx_to_swap, heap)
                currentIdx = idx_to_swap
                child_one_idx = currentIdx * 2 + 1
            else:
                return

    def siftUp(self, currentIdx, heap):
        parentIdx = (currentIdx - 1) // 2
        while currentIdx > 0 and heap[currentIdx][1] < heap[parentIdx][1]:
            self.swap(currentIdx, parentIdx, heap)
            currentIdx = parentIdx
            parentIdx = (currentIdx - 1) // 2

    def remove(self):
        if self.isEmpty(): return None
        self.swap(0, len(self.heap) - 1, self.heap)
        vertex, distance = self.heap.pop()
        self.vertexMap.pop(vertex)
        self.siftDown(0, len(self.heap) - 1, self.heap)
        return vertex, distance

    def swap(self, i, j, heap):
        self.vertexMap[heap[i][0]] = j
        self.vertexMap[heap[j][0]] = i
        heap[i], heap[j] = heap[j], heap[i]

    def update(self, vertex, value):
        self.heap[self.vertexMap[vertex]] = (vertex, value)
        self.siftUp(self.vertexMap[vertex], self.heap)

# %%
# Dijkstra clássico (O(V²+E)) – versão da aula
def dijkstra_classico(start, edges):
    n = len(edges)
    INF = float('inf')
    dist = [INF] * n
    visited = [False] * n
    dist[start] = 0

    for _ in range(n):
        # vértice não visitado com menor distância (busca linear)
        v = -1
        best = INF
        for i in range(n):
            if not visited[i] and dist[i] < best:
                best = dist[i]
                v = i
        if v == -1 or best == INF:   # restante inacessível
            break
        visited[v] = True
        for to, w in edges[v]:
            if not visited[to]:
                nd = best + w
                if nd < dist[to]:
                    dist[to] = nd
    return [-1 if x == INF else x for x in dist]

# %%
# Dijkstra com Min‑Heap (O((V+E)logV)) – versão da aula
def dijkstra_min_heap(start, edges):
    n = len(edges)
    INF = float('inf')
    dist = [INF] * n
    dist[start] = 0

    heap = MinHeap([(i, INF) for i in range(n)])
    heap.update(start, 0)

    while not heap.isEmpty():
        v, d = heap.remove()
        if d != dist[v]:          # ignore outdated entry
            continue
        for to, w in edges[v]:
            nd = d + w
            if nd < dist[to]:
                dist[to] = nd
                heap.update(to, nd)
    return [-1 if x == INF else x for x in dist]

# %%
def medir_tempo(func, *args):
    t0 = time.time()
    _ = func(*args)
    return time.time() - t0

def medir_com_codecarbon(func, *args):
    tracker = EmissionsTracker()
    tracker.start()
    elapsed = medir_tempo(func, *args)
    co2 = tracker.stop()
    return elapsed, co2

# %%
def gerar_grafo(n, p=0.01, peso_min=1, peso_max=10):
    G = nx.gnp_random_graph(n, p, seed=SEED, directed=True)
    # componente gigante
    if not nx.is_strongly_connected(G):
        comp = nx.strongly_connected_components(G)
        giant = max(comp, key=len)
        G = G.subgraph(giant).copy()
        # adiciona arestas aleatórias até ficar fortemente conectado
        while not nx.is_strongly_connected(G):
            u, v = random.sample(list(G.nodes), 2)
            if not G.has_edge(u, v):
                w = random.randint(peso_min, peso_max)
                G.add_edge(u, v, weight=w)
    for u, v in G.edges():
        G[u][v]['weight'] = random.randint(peso_min, peso_max)
    return G

# %%
tamanhos = [100, 500, 1_000, 5_000, 10_000, 50_000]
repeticoes_por_tamanho = 15          # 15‑20 recomendado;
sources_por_rep = 5                 # número de fontes por repetição

resultados = []   # lista de dicts

for n in tamanhos:
    p = max(0.005, 1e-5 * n) if n <= 10_000 else 0.0002
    print(f'Gerando grafo com {n} nós (p={p:.5f})...')
    G = gerar_grafo(n, p=p)

    # ---- Conversão para a estrutura esperada pelos algoritmos ----
    adj = [[] for _ in range(n)]
    for u, nbrs in G.adjacency():
        for v, data in nbrs.items():
            adj[u].append([v, data['weight']])

    for rep in range(repeticoes_por_tamanho):
        max_src = min(sources_por_rep, len(G))
        sources = random.sample(list(G.nodes), max_src)

        for s in sources:
            # ----- Dijkstra clássico -----
            t_c, co2_c = medir_com_codecarbon(dijkstra_classico, s, adj)
            resultados.append({
                'n': n,
                'algoritmo': 'classico',
                'tempo': t_c,
                'co2': co2_c
            })

            # ----- Dijkstra com heap -----
            t_h, co2_h = medir_com_codecarbon(dijkstra_min_heap, s, adj)
            resultados.append({
                'n': n,
                'algoritmo': 'heap',
                'tempo': t_h,
                'co2': co2_h
            })

            # ----- NetworkX (referência) -----
            t_n, co2_n = medir_com_codecarbon(
                lambda start: nx.single_source_dijkstra_path_length(G, start, weight='weight'),
                s
            )
            resultados.append({
                'n': n,
                'algoritmo': 'networkx',
                'tempo': t_n,
                'co2': co2_n
            })
# Out:
# [codecarbon WARNING @ 22:50:10] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 22:50:10] [setup] RAM Tracking...
# [codecarbon INFO @ 22:50:10] [setup] CPU Tracking...
# Gerando grafo com 100 nós (p=0.00500)...
# [codecarbon WARNING @ 22:50:11] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon WARNING @ 22:50:11] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 22:50:11] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon WARNING @ 22:50:11] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 22:50:11] [setup] GPU Tracking...
# [codecarbon INFO @ 22:50:11] No GPU found.
# [codecarbon INFO @ 22:50:11] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 22:50:11] >>> Tracker's metadata:
# [codecarbon INFO @ 22:50:11]   Platform system: Linux-6.6.105+-x86_64-with-glibc2.35
# [codecarbon INFO @ 22:50:11]   Python version: 3.12.12
# [codecarbon INFO @ 22:50:11]   CodeCarbon version: 3.0.7
# [codecarbon INFO @ 22:50:11]   Available RAM : 12.671 GB
# [codecarbon INFO @ 22:50:11]   CPU count: 2 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 22:50:11]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 22:50:11]   GPU count: None
# [codecarbon INFO @ 22:50:11]   GPU model: None
# [codecarbon INFO @ 22:50:11] Emissions data (if any) will be saved to file /content/emissions.csv
# [codecarbon INFO @ 22:50:12] Energy consumed for RAM : 0.000000 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 22:50:12] Delta energy consumed for CPU with constant : 0.000000 kWh, power : 42.5 W
# [codecarbon INFO @ 22:50:12] Energy consumed for All CPU : 0.000000 kWh
# [codecarbon INFO @ 22:50:12] 0.000000 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 22:50:12] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 22:50:12] [setup] RAM Tracking...
# [codecarbon INFO @ 22:50:12] [setup] CPU Tracking...
# [codecarbon WARNING @ 22:50:13] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon WARNING @ 22:50:13] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 22:50:13] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon WARNING @ 22:50:13] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 22:50:13] [setup] GPU Tracking...
# [codecarbon INFO @ 22:50:13] No GPU found.
# [codecarbon INFO @ 22:50:13] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 22:50:13] >>> Tracker's metadata:
# [codecarbon INFO @ 22:50:13]   Platform system: Linux-6.6.105+-x86_64-with-glibc2.35
# [codecarbon INFO @ 22:50:13]   Python version: 3.12.12
# [codecarbon INFO @ 22:50:13]   CodeCarbon version: 3.0.7
# [codecarbon INFO @ 22:50:13]   Available RAM : 12.671 GB
# [codecarbon INFO @ 22:50:13]   CPU count: 2 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 22:50:13]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 22:50:13]   GPU count: None
# [codecarbon INFO @ 22:50:13]   GPU model: None
# [codecarbon INFO @ 22:50:13] Emissions data (if any) will be saved to file /content/emissions.csv
# [codecarbon INFO @ 22:50:13] Energy consumed for RAM : 0.000000 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 22:50:13] Delta energy consumed for CPU with constant : 0.000000 kWh, power : 42.5 W
# [codecarbon INFO @ 22:50:13] Energy consumed for All CPU : 0.000000 kWh
# [codecarbon INFO @ 22:50:13] 0.000000 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 22:50:13] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 22:50:13] [setup] RAM Tracking...
# [codecarbon INFO @ 22:50:13] [setup] CPU Tracking...
# [codecarbon WARNING @ 22:50:15] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon WARNING @ 22:50:15] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 22:50:15] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon WARNING @ 22:50:15] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 22:50:15] [setup] GPU Tracking...
# [codecarbon INFO @ 22:50:15] No GPU found.
# [codecarbon INFO @ 22:50:15] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 22:50:15] >>> Tracker's metadata:
# [codecarbon INFO @ 22:50:15]   Platform system: Linux-6.6.105+-x86_64-with-glibc2.35
# [codecarbon INFO @ 22:50:15]   Python version: 3.12.12
# [codecarbon INFO @ 22:50:15]   CodeCarbon version: 3.0.7
# [codecarbon INFO @ 22:50:15]   Available RAM : 12.671 GB
# [codecarbon INFO @ 22:50:15]   CPU count: 2 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 22:50:15]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 22:50:15]   GPU count: None
# [codecarbon INFO @ 22:50:15]   GPU model: None
# [codecarbon INFO @ 22:50:15] Emissions data (if any) will be saved to file /content/emissions.csv
# [codecarbon INFO @ 22:50:15] Energy consumed for RAM : 0.000000 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 22:50
The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 23:57:12] >>> Tracker's metadata:
# [codecarbon INFO @ 23:57:12]   Platform system: Linux-6.6.105+-x86_64-with-glibc2.35
# [codecarbon INFO @ 23:57:12]   Python version: 3.12.12
# [codecarbon INFO @ 23:57:12]   CodeCarbon version: 3.0.7
# [codecarbon INFO @ 23:57:12]   Available RAM : 12.671 GB
# [codecarbon INFO @ 23:57:12]   CPU count: 2 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 23:57:12]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 23:57:12]   GPU count: None
# [codecarbon INFO @ 23:57:12]   GPU model: None
# [codecarbon INFO @ 23:57:12] Emissions data (if any) will be saved to file /content/emissions.csv
# [codecarbon INFO @ 23:57:27] Energy consumed for RAM : 0.000042 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:57:27] Delta energy consumed for CPU with constant : 0.000178 kWh, power : 42.5 W
# [codecarbon INFO @ 23:57:27] Energy consumed for All CPU : 0.000178 kWh
# [codecarbon INFO @ 23:57:27] 0.000219 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:57:42] Energy consumed for RAM : 0.000083 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:57:42] Delta energy consumed for CPU with constant : 0.000176 kWh, power : 42.5 W
# [codecarbon INFO @ 23:57:42] Energy consumed for All CPU : 0.000354 kWh
# [codecarbon INFO @ 23:57:42] 0.000437 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:57:57] Energy consumed for RAM : 0.000125 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:57:57] Delta energy consumed for CPU with constant : 0.000177 kWh, power : 42.5 W
# [codecarbon INFO @ 23:57:57] Energy consumed for All CPU : 0.000531 kWh
# [codecarbon INFO @ 23:57:57] 0.000655 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:12] Energy consumed for RAM : 0.000166 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:58:12] Delta energy consumed for CPU with constant : 0.000177 kWh, power : 42.5 W
# [codecarbon INFO @ 23:58:12] Energy consumed for All CPU : 0.000707 kWh
# [codecarbon INFO @ 23:58:12] 0.000874 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:27] Energy consumed for RAM : 0.000208 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:58:27] Delta energy consumed for CPU with constant : 0.000177 kWh, power : 42.5 W
# [codecarbon INFO @ 23:58:27] Energy consumed for All CPU : 0.000884 kWh
# [codecarbon INFO @ 23:58:27] 0.001092 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:42] Energy consumed for RAM : 0.000249 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:58:42] Delta energy consumed for CPU with constant : 0.000177 kWh, power : 42.5 W
# [codecarbon INFO @ 23:58:42] Energy consumed for All CPU : 0.001061 kWh
# [codecarbon INFO @ 23:58:42] 0.001310 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:57] Energy consumed for RAM : 0.000291 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:58:57] Delta energy consumed for CPU with constant : 0.000177 kWh, power : 42.5 W
# [codecarbon INFO @ 23:58:57] Energy consumed for All CPU : 0.001238 kWh
# [codecarbon INFO @ 23:58:57] 0.001529 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:59:12] Energy consumed for RAM : 0.000332 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 23:59:12] Delta energy consumed for CPU with constant : 0.000176 kWh, power : 42.5 W
# [codecarbon INFO @ 23:59:12] Energy consumed for All CPU : 0.001414 kWh
# [codecarbon INFO @ 23:59:12] 0.001746 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:59:12] 0.004151 g.CO2eq/s mean an estimation of 130.91484349901594 kg.CO2eq/year

# %%
df = pd.DataFrame(resultados)

def ic(series, alpha=0.95):
    mean = series.mean()
    sem = stats.sem(series)
    ci = sem * stats.t.ppf((1 + alpha) / 2., len(series) - 1)
    return mean, ci

agg = df.groupby(['n', 'algoritmo']).agg(
    tempo_medio=('tempo', 'mean'),
    tempo_std=('tempo', 'std'),
    co2_medio=('co2', 'mean'),
    co2_std=('co2', 'std')
).reset_index()

# %%
plt.figure(figsize=(8, 4))
for alg in ['classico', 'heap', 'networkx']:
    sub = agg[agg.algoritmo == alg]
    plt.errorbar(sub['n'], sub['tempo_medio'],
                 yerr=sub['tempo_std'], label=alg, marker='o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Número de nós')
plt.ylabel('Tempo (s) – média ± desvio')
plt.legend()
plt.tight_layout()
plt.savefig('tempo.png')
plt.show()

plt.figure(figsize=(8, 4))
for alg in ['classico', 'heap', 'networkx']:
    sub = agg[agg.algoritmo == alg]
    plt.errorbar(sub['n'], sub['co2_medio'],
                 yerr=sub['co2_std'], label=alg, marker='o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Número de nós')
plt.ylabel('CO₂ (kg) – média ± desvio')
plt.legend()
plt.tight_layout()
plt.savefig('co2.png')
plt.show()

# %%
# opcional
df.to_csv('resultados_raw.csv', index=False)
agg.to_csv('resultados_agg.csv', index=False)

print('Experimento concluído – arquivos "tempo.png" e "co2.png" gerados.')
